# %%
import json
from dataclasses import dataclass, asdict
from timeit import default_timer
import numpy as np

# %%
with open('basis_sets/3-21G') as f:
    lines = f.readlines()

# %%
lines = [k for i in lines if (k := i.strip()) != '']
lines = [k for k in lines if k[0] != "!"]

# %%
lines
# Out:
# ['{',
#  'keys= { turbomole= }',
#  'data= {',
#  'H:3-21G',
#  '{',
#  '2  s',
#  '5.4471780              0.1562850',
#  '0.8245470              0.9046910',
#  '1  s',
#  '0.1831920              1.0000000',
#  '}',
#  'He:3-21G',
#  '{',
#  '2  s',
#  '13.6267000              0.1752300',
#  '1.9993500              0.8934830',
#  '1  s',
#  '0.3829930              1.0000000',
#  '}',
#  'Li:3-21G',
#  '{',
#  '3  s',
#  '36.8382000              0.0696686',
#  '5.4817200              0.3813460',
#  '1.1132700              0.6817020',
#  '2  s',
#  '0.5402050             -0.2631270',
#  '0.1022550              1.1433900',
#  '1  s',
#  '0.0285650              1.0000000',
#  '2  p',
#  '0.5402050              0.1615460',
#  '0.1022550              0.9156630',
#  '1  p',
#  '0.0285650              1.0000000',
#  '}',
#  'Be:3-21G',
#  '{',
#  '3  s',
#  '71.8876000              0.0644263',
#  '10.7289000              0.3660960',
#  '2.2220500              0.6959340',
#  '2  s',
#  '1.2954800             -0.4210640',
#  '0.2688810              1.2240700',
#  '1  s',
#  '0.0773500              1.0000000',
#  '2  p',
#  '1.2954800              0.2051320',
#  '0.2688810              0.8825280',
#  '1  p',
#  '0.0773500              1.0000000',
#  '}',
#  'B:3-21G',
#  '{',
#  '3  s',
#  '116.4340000              0.0629605',
#  '17.4314000              0.3633040',
#  '3.6801600              0.6972550',
#  '2  s',
#  '2.2818700             -0.3686620',
#  '0.4652480              1.1994400',
#  '1  s',
#  '0.1243280              1.0000000',
#  '2  p',
#  '2.2818700              0.2311520',
#  '0.4652480              0.8667640',
#  '1  p',
#  '0.1243280              1.0000000',
#  '}',
#  'C:3-21G',
#  '{',
#  '3  s',
#  '172.2560000              0.0617669',
#  '25.9109000              0.3587940',
#  '5.5333500              0.7007130',
#  '2  s',
#  '3.6649800             -0.3958970',
#  '0.7705450              1.2158400',
#  '1  s',
#  '0.1958570              1.0000000',
#  '2  p',
#  '3.6649800              0.2364600',
#  '0.7705450              0.8606190',
#  '1  p',
#  '0.1958570              1.0000000',
#  '}',
#  'N:3-21G',
#  '{',
#  '3  s',
#  '242.7660000              0.0598657',
#  '36.4851000              0.3529550',
#  '7.8144900              0.7065130',
#  '2  s',
#  '5.4252200             -0.4133010',
#  '1.1491500              1.2244200',
#  '1  s',
#  '0.2832050              1.0000000',
#  '2  p',
#  '5.4252200              0.2379720',
#  '1.1491500              0.8589530',
#  '1  p',
#  '0.2832050              1.0000000',
#  '}',
#  'O:3-21G',
#  '{',
#  '3  s',
#  '322.0370000              0.0592394',
#  '48.4308000              0.3515000',
#  '10.4206000              0.7076580',
#  '2  s',
#  '7.4029400             -0.4044530',
#  '1.5762000              1.2215600',
#  '1  s',
#  '0.3736840              1.0000000',
#  '2  p',
#  '7.4029400              0.2445860',
#  '1.5762000              0.8539550',
#  '1  p',
#  '0.3736840              1.0000000',
#  '}',
#  'F:3-21G',
#  '{',
#  '3  s',
#  '413.8010000              0.0585483',
#  '62.2446000              0.3493080',
#  '13.4340000              0.7096320',
#  '2  s',
#  '9.7775900             -0.4073270',
#  '2.0861700              1.2231400',
#  '1  s',
#  '0.4823830              1.0000000',
#  '2  p',
#  '9.7775900              0.2466800',
#  '2.0861700              0.8523210',
#  '1  p',
#  '0.4823830              1.0000000',
#  '}',
#  'Ne:3-21G',
#  '{',
#  '3  s',
#  '515.7240000              0.0581430',
#  '77.6538000              0.3479510',
#  '16.8136000              0.7107140',
#  '2  s',
#  '12.4830000             -0.4099220',
#  '2.6645100              1.2243100',
#  '1  s',
#  '0.6062500              1.0000000',
#  '2  p',
#  '12.4830000              0.2474600',
#  '2.6645100              0.8517430',
#  '1  p',
#  '0.6062500              1.0000000',
#  '}',
#  'Na:3-21G',
#  '{',
#  '3  s',
#  '547.6130000              0.0674911',
#  '82.0678000              0.3935050',
#  '17.6917000              0.6656050',
#  '3  s',
#  '17.5407000             -0.1119370',
#  '3.7939800              0.2546540',
#  '0.9064410              0.8444170',
#  '2  s',
#  '0.5018240             -0.2196600',
#  '0.0609458              1.0891200',
#  '1  s',
#  '0.0244349              1.0000000',
#  '3  p',
#  '17.5407000              0.1282330',
#  '3.7939800              0.4715330',
#  '0.9064410              0.6042730',
#  '2  p',
#  '0.5018240              0.0090665',
#  '0.0609458              0.9972020',
#  '1  p',
#  '0.0244349              1.0000000',
#  '}',
#  'Mg:3-21G',
#  '{',
#  '3  s',
#  '652.8410000              0.0675982',
#  '98.3805000              0.3917780',
#  '21.2996000              0.6666610',
#  '3  s',
#  '23.3727000             -0.1102460',
#  '5.1995300              0.1841190',
#  '1.3150800              0.8963990',
#  '2  s',
#  '0.6113490             -0.3611010',
#  '0.1418410              1.2150500',
#  '1  s',
#  '0.0464011              1.0000000',
#  '3  p',
#  '23.3727000              0.1210140',
#  '5.1995300              0.4628100',
#  '1.3150800              0.6069070',
#  '2  p',
#  '0.6113490              0.0242633',
#  '0.1418410              0.9866730',
#  '1  p',
#  '0.0464011              1.0000000',
#  '}',
#  'Al:3-21G',
#  '{',
#  '3  s',
#  '775.7370000              0.0668347',
#  '116.9520000              0.3890610',
#  '25.3326000              0.6694680',
#  '3  s',
#  '29.4796000             -0.1079020',
#  '6.6331400              0.1462450',
#  '1.7267500              0.9237300',
#  '2  s',
#  '0.9461600             -0.3203270',
#  '0.2025060              1.1841200',
#  '1  s',
#  '0.0639088              1.0000000',
#  '3  p',
#  '29.4796000              0.1175740',
#  '6.6331400              0.4611740',
#  '1.7267500              0.6055350',
#  '2  p',
#  '0.9461600              0.0519383',
#  '0.2025060              0.9726600',
#  '1  p',
#  '0.0639088              1.0000000',
#  '}',
#  'Si:3-21G',
#  '{',
#  '3  s',
#  '910.6550000              0.0660823',
#  '137.3360000              0.3862290',
#  '29.7601000              0.6723800',
#  '3  s',
#  '36.6716000             -0.1045110',
#  '8.3172900              0.1074100',
#  '2.2164500              0.9514460',
#  '2  s',
#  '1.0791300             -0.3761080',
#  '0.3024220              1.2516500',
#  '1  s',
#  '0.0933392              1.0000000',
#  '3  p',
#  '36.6716000              0.1133550',
#  '8.3172900              0.4575780',
#  '2.2164500              0.6074270',
#  '2  p',
#  '1.0791300              0.0671030',
#  '0.3024220              0.9568830',
#  '1  p',
#  '0.0933392              1.0000000',
#  '}',
#  'P:3-21G',
#  '{',
#  '3  s',
#  '1054.9000000              0.0655410',
#  '159.1950000              0.3840360',
#  '34.5304000              0.6745410',
#  '3  s',
#  '44.2866000             -0.1021300',
#  '10.1019000              0.0815920',
#  '2.7399700              0.9697880',
#  '2  s',
#  '1.2186500             -0.3714950',
#  '0.3955460              1.2709900',
#  '1  s',
#  '0.1228110              1.0000000',
#  '3  p',
#  '44.2866000              0.1108510',
#  '10.1019000              0.4564950',
#  '2.7399700              0.6069360',
#  '2  p',
#  '1.2186500              0.0915820',
#  '0.3955460              0.9349240',
#  '1  p',
#  '0.1228110              1.0000000',
#  '}',
#  'S:3-21G',
#  '{',
#  '3  s',
#  '1210.6200000              0.0650070',
#  '182.7470000              0.3820400',
#  '39.6673000              0.6765450',
#  '3  s',
#  '52.2236000             -0.1003100',
#  '11.9629000              0.0650880',
#  '3.2891100              0.9814550',
#  '2  s',
#  '1.2238400             -0.2860890',
#  '0.4573030              1.2280600',
#  '1  s',
#  '0.1422690              1.0000000',
#  '3  p',
#  '52.2236000              0.1096460',
#  '11.9629000              0.4576490',
#  '3.2891100              0.6042610',
#  '2  p',
#  '1.2238400              0.1647770',
#  '0.4573030              0.8708550',
#  '1  p',
#  '0.1422690              1.0000000',
#  '}',
#  'Cl:3-21G',
#  '{',
#  '3  s',
#  '1376.4000000              0.0645827',
#  '207.8570000              0.3803630',
#  '45.1554000              0.6781900',
#  '3  s',
#  '60.8014000             -0.0987639',
#  '13.9765000              0.0511338',
#  '3.8871000              0.9913370',
#  '2  s',
#  '1.3529900             -0.2224010',
#  '0.5269550              1.1825200',
#  '1  s',
#  '0.1667140              1.0000000',
#  '3  p',
#  '60.8014000              0.1085980',
#  '13.9765000              0.4586820',
#  '3.8871000              0.6019620',
#  '2  p',
#  '1.3529900              0.2192160',
#  '0.5269550              0.8223210',
#  '1  p',
#  '0.1667140              1.0000000',
#  '}',
#  'Ar:3-21G',
#  '{',
#  '3  s',
#  '1553.7100000              0.0641707',
#  '234.6780000              0.3787970',
#  '51.0121000              0.6797520',
#  '3  s',
#  '70.0453000             -0.0974661',
#  '16.1473000              0.0390569',
#  '4.5349200              0.9999160',
#  '2  s',
#  '1.5420900             -0.1768660',
#  '0.6072670              1.1469000',
#  '1  s',
#  '0.1953730              1.0000000',
#  '3  p',
#  '70.0453000              0.1076190',
#  '16.1473000              0.4595760',
#  '4.5349200              0.6000410',
#  '2  p',
#  '1.5420900              0.2556870',
#  '0.6072670              0.7898420',
#  '1  p',
#  '0.1953730              1.0000000',
#  '}',
#  'K:3-21G',
#  '{',
#  '3  s',
#  '1721.1755000              0.0648747',
#  '260.0163300              0.3808593',
#  '56.6245540              0.6773681',
#  '3  s',
#  '71.5572000             -0.1093429',
#  '15.4389400              0.1130640',
#  '4.4745510              0.9462575',
#  '3  s',
#  '4.1212750             -0.2699730',
#  '1.1886210              0.3646323',
#  '0.3756740              0.8107533',
#  '2  s',
#  '0.2445770             -0.2688250',
#  '0.0389720              1.1289830',
#  '1  s',
#  '0.0160630              1.0000000',
#  '3  p',
#  '71.5572000              0.1339654',
#  '15.4389400              0.5302673',
#  '4.4745510              0.5117992',
#  '3  p',
#  '4.1212750              0.01994922',
#  '1.1886210              0.43402130',
#  '0.3756740              0.64532260',
#  '2  p',
#  '0.2445770              0.0003081035',
#  '0.0389720              0.9998787',
#  '1  p',
#  '0.0160630              1.0000000',
#  '}',
#  'Ca:3-21G',
#  '{',
#  '3  s',
#  '1915.4348000              0.0646240',
#  '289.5332400              0.3798380',
#  '63.1063520              0.6783290',
#  '3  s',
#  '80.3974400             -0.1093030',
#  '17.3307500              0.1089000',
#  '5.0836240              0.9492770',
#  '3  s',
#  '4.7822290             -0.2816070',
#  '1.4625580              0.3410510',
#  '0.4792230              0.8381040',
#  '2  s',
#  '0.4396820             -0.2697050',
#  '0.0591300              1.1132930',
#  '1  s',
#  '0.0238970              1.0000000',
#  '3  p',
#  '80.3974400              0.1354330',
#  '17.3307500              0.5372220',
#  '5.0836240              0.5018040',
#  '3  p',
#  '4.7822290              0.0190090',
#  '1.4625580              0.4360380',
#  '0.4792230              0.6386710',
#  '2  p',
#  '0.4396820              0.0003080',
#  '0.0591300              0.9998960',
#  '1  p',
#  '0.0238970              1.0000000',
#  '}',
#  'Sc:3-21G',
#  '{',
#  '3  s',
#  '2119.8870000              0.0644210',
#  '320.4299000              0.3791600',
#  '69.8989300              0.6789630',
#  '3  s',
#  '89.7645000             -0.1093840',
#  '19.3851000              0.1050700',
#  '5.7314230              0.9522050',
#  '3  s',
#  '5.4919380             -0.2852110',
#  '1.7437420              0.3241550',
#  '0.5662270              0.8565920',
#  '2  s',
#  '0.5168020             -0.2626780',
#  '0.0672140              1.1080790',
#  '1  s',
#  '0.0259850              1.0000000',
#  '3  p',
#  '89.7645000              0.1363280',
#  '19.3851000              0.5418600',
#  '5.7314230              0.4950550',
#  '3  p',
#  '5.4919380              0.0176140',
#  '1.7437420              0.4336450',
#  '0.5662270              0.6425510',
#  '2  p',
#  '0.5168020              0.0003270',
#  '0.0672140              0.9998930',
#  '1  p',
#  '0.0259850              1.0000000',
#  '2  d',
#  '5.7222150              0.2652360',
#  '1.3608490              0.8558610',
#  '1  d',
#  '0.3226520              1.0000000',
#  '}',
#  'Ti:3-21G',
#  '{',
#  '3  s',
#  '2335.0200000              0.0642170',
#  '353.0441000              0.3784120',
#  '77.0584500              0.6796810',
#  '3  s',
#  '99.5738700             -0.1094720',
#  '21.5467100              0.1019430',
#  '6.4139650              0.9546220',
#  '3  s',
#  '6.2382790             -0.2861370',
#  '1.9961080              0.3218280',
#  '0.6464900              0.8595510',
#  '2  s',
#  '0.5732850             -0.2424500',
#  '0.0731190              1.1000750',
#  '1  s',
#  '0.0265380              1.0000000',
#  '3  p',
#  '99.5738700              0.1372970',
#  '21.5467100              0.5458750',
#  '6.4139650              0.4890680',
#  '3  p',
#  '6.2382790              0.0192370',
#  '1.9961080              0.4404420',
#  '0.6464900              0.6356200',
#  '2  p',
#  '0.5732850              0.0002920',
#  '0.0731190              0.9999070',
#  '1  p',
#  '0.0265380              1.0000000',
#  '2  d',
#  '7.0836660              0.2629210',
#  '1.7096340              0.8557720',
#  '1  d',
#  '0.4141230              1.0000000',
#  '}',
#  'V:3-21G',
#  '{',
#  '3  s',
#  '2563.8770000              0.0639480',
#  '387.5340000              0.3775940',
#  '84.5982300              0.6805420',
#  '3  s',
#  '109.7938000             -0.1098360',
#  '23.7692100              0.1007070',
#  '7.1229610              0.9556330',
#  '3  s',
#  '6.9812040             -0.2884590',
#  '2.2198390              0.3364360',
#  '0.7198030              0.8481900',
#  '2  s',
#  '0.6312620             -0.2364900',
#  '0.0800620              1.0977210',
#  '1  s',
#  '0.0288650              1.0000000',
#  '3  p',
#  '109.7938000              0.1384210',
#  '23.7692100              0.5504890',
#  '7.1229610              0.4824170',
#  '3  p',
#  '6.9812040              0.0218210',
#  '2.2198390              0.4567620',
#  '0.7198030              0.6186750',
#  '2  p',
#  '0.6312620              0.0001900',
#  '0.0800620              0.9999400',
#  '1  p',
#  '0.0288650              1.0000000',
#  '2  d',
#  '8.3429170              0.2640620',
#  '2.0329440              0.8539660',
#  '1  d',
#  '0.4957120              1.0000000',
#  '}',
#  'Cr:3-21G',
#  '{',
#  '3  s',
#  '2798.2940000              0.0638240',
#  '423.1370000              0.3770840',
#  '92.4388600              0.6809890',
#  '3  s',
#  '120.2806000             -0.1177790',
#  '26.0372700              0.1014310',
#  '7.8441720              0.9571980',
#  '3  s',
#  '7.7932760             -0.2888570',
#  '2.4971960              0.3351150',
#  '0.8051420              0.8502480',
#  '2  s',
#  '0.7039210             -0.2322510',
#  '0.0861620              1.0936710',
#  '1  s',
#  '0.0321990              1.0000000',
#  '3  p',
#  '120.2806000              0.1398780',
#  '26.0372700              0.5559830',
#  '7.8441720              0.4748180',
#  '3  p',
#  '7.7932760              0.0221850',
#  '2.4971960              0.4616250',
#  '0.8051420              0.6145390',
#  '2  p',
#  '0.7039210              0.0001800',
#  '0.0861620              0.9999450',
#  '1  p',
#  '0.0321990              1.0000000',
#  '2  d',
#  '9.6253390              0.2655960',
#  '2.3622640              0.8521560',
#  '1  d',
#  '0.5770940              1.0000000',
#  '}',
#  'Mn:3-21G',
#  '{',
#  '3  s',
#  '3041.6860000              0.0637450',
#  '460.0901000              0.3767490',
#  '100.5958000              0.6812470',
#  '3  s',
#  '131.7673000             -0.1102960',
#  '28.5691500              0.0981900',
#  '8.6605010              0.9576590',
#  '3  s',
#  '8.5690810             -0.2917140',
#  '2.7681780              0.3439630',
#  '0.8872880              0.8451980',
#  '2  s',
#  '0.7674430             -0.2300040',
#  '0.0920250              1.0914500',
#  '1  s',
#  '0.0332650              1.0000000',
#  '3  p',
#  '131.7673000              0.1404540',
#  '28.5691500              0.5578020',
#  '8.6605010              0.4715010',
#  '3  p',
#  '8.5690810              0.0242240',
#  '2.7681780              0.4686600',
#  '0.8872880              0.6074210',
#  '2  p',
#  '0.7674430              0.0003080',
#  '0.0920250              0.9999070',
#  '1  p',
#  '0.0332650              1.0000000',
#  '2  d',
#  '11.0688400              0.2652720',
#  '2.7307070              0.8517950',
#  '1  d',
#  '0.6685090              1.0000000',
#  '}',
#  'Fe:3-21G',
#  '{',
#  '3  s',
#  '3299.1840000              0.0635860',
#  '499.0886000              0.3762020',
#  '109.1614000              0.6817850',
#  '3  s',
#  '143.4652000             -0.1105520',
#  '31.1685800              0.0968470',
#  '9.4836120              0.9587970',
#  '3  s',
#  '9.4645650             -0.2920560',
#  '3.1003730              0.3375240',
#  '0.9864930              0.8519420',
#  '2  s',
#  '0.8534120             -0.2279440',
#  '0.0988120              1.0882870',
#  '1  s',
#  '0.0364420              1.0000000',
#  '3  p',
#  '143.4652000              0.1411010',
#  '31.1685800              0.5603870',
#  '9.4836120              0.4676440',
#  '3  p',
#  '9.4645650              0.0237620',
#  '3.1003730              0.4689110',
#  '0.9864930              0.6083110',
#  '2  p',
#  '0.8534120             -0.0004260',
#  '0.0988120              1.0001240',
#  '1  p',
#  '0.0364420              1.0000000',
#  '2  d',
#  '12.3544900              0.2686110',
#  '3.0556050              0.8492720',
#  '1  d',
#  '0.7385910              1.0000000',
#  '}',
#  'Co:3-21G',
#  '{',
#  '3  s',
#  '3564.7620000              0.0634870',
#  '539.3908000              0.3758180',
#  '118.0449000              0.6821220',
#  '3  s',
#  '155.4382000             -0.1109870',
#  '33.8156100              0.0967670',
#  '10.3332300              0.9589920',
#  '3  s',
#  '10.3815200             -0.2922620',
#  '3.3827140              0.3432510',
#  '1.0769540              0.8469630',
#  '2  s',
#  '0.9090150             -0.2174600',
#  '0.1050410              1.0849980',
#  '1  s',
#  '0.0372570              1.0000000',
#  '3  p',
#  '155.4382000              0.1420640',
#  '33.8156100              0.5634440',
#  '10.3332300              0.4630240',
#  '3  p',
#  '10.3815200              0.0263130',
#  '3.3827140              0.4769170',
#  '1.0769540              0.5991540',
#  '2  p',
#  '0.9090150              0.0002280',
#  '0.1050410              0.9999340',
#  '1  p',
#  '0.0372570              1.0000000',
#  '2  d',
#  '13.7407000              0.2709550',
#  '3.4089830              0.8473420',
#  '1  d',
#  '0.8186410              1.0000000',
#  '}',
#  'Ni:3-21G',
#  '{',
#  '3  s',
#  '3848.0050000              0.0632660',
#  '582.0307000              0.3751710',
#  '127.3674000              0.6828240',
#  '3  s',
#  '168.2896000             -0.1111150',
#  '36.6563300              0.0953240',
#  '11.2321200              0.9601610',
#  '3  s',
#  '11.3587700             -0.2920600',
#  '3.7388460              0.3375410',
#  '1.1824630              0.8525330',
#  '2  s',
#  '0.9889040             -0.2136870',
#  '0.1110250              1.0819330',
#  '1  s',
#  '0.0392580              1.0000000',
#  '3  p',
#  '168.2896000              0.1424900',
#  '36.6563300              0.5655470',
#  '11.2321200              0.4599930',
#  '3  p',
#  '11.3587700              0.0261380',
#  '3.7388460              0.4765980',
#  '1.1824630              0.6003800',
#  '2  p',
#  '0.9889040              0.0002940',
#  '0.1110250              0.9999170',
#  '1  p',
#  '0.0392580              1.0000000',
#  '2  d',
#  '15.2206900              0.2726060',
#  '3.7860200              0.8459280',
#  '1  d',
#  '0.9045570              1.0000000',
#  '}',
#  'Cu:3-21G',
#  '{',
#  '3  s',
#  '4134.3020000              0.0631880',
#  '625.4912000              0.3748450',
#  '136.9556000              0.6831000',
#  '3  s',
#  '181.4960000             -0.1113200',
#  '39.5743100              0.0944870',
#  '12.1624600              0.9608790',
#  '3  s',
#  '12.3511100             -0.2922230',
#  '4.0496510              0.3429910',
#  '1.2792250              0.8479460',
#  '2  s',
#  '1.0498040             -0.2065080',
#  '0.1169330              1.0792730',
#  '1  s',
#  '0.0007510              1.0000000',
#  '3  p',
#  '181.4960000              0.1430840',
#  '39.5743100              0.5677560',
#  '12.1624600              0.4567140',
#  '3  p',
#  '12.3511100              0.0277270',
#  '4.0496510              0.4835240',
#  '1.2792250              0.5929780',
#  '2  p',
#  '1.0498040              0.0001390',
#  '0.1169330              0.9999610',
#  '1  p',
#  '0.0007510              1.0000000',
#  '2  d',
#  '16.7593800              0.2741120',
#  '4.1789770              0.8446250',
#  '1  d',
#  '0.9943270              1.0000000',
#  '}',
#  'Zn:3-21G',
#  '{',
#  '3  s',
#  '4432.2880000              0.0630930',
#  '670.6601000              0.3745040',
#  '146.9024000              0.6834160',
#  '3  s',
#  '195.0042000             -0.1116280',
#  '42.5688900              0.0943360',
#  '13.1214300              0.9611000',
#  '3  s',
#  '13.4023100             -0.2917810',
#  '4.3999060              0.3426140',
#  '1.3851480              0.8482840',
#  '2  s',
#  '1.1215580             -0.2023710',
#  '0.1229440              1.0770350',
#  '1  s',
#  '0.0421930              1.0000000',
#  '3  p',
#  '195.0042000              0.1438060',
#  '42.5688900              0.5700020',
#  '13.1214300              0.4533120',
#  '3  p',
#  '13.4023100              0.0287050',
#  '4.3999060              0.4862520',
#  '1.3851480              0.5902350',
#  '2  p',
#  '1.1215580              0.0003440',
#  '0.1229440              0.9999050',
#  '1  p',
#  '0.0421930              1.0000000',
#  '2  d',
#  '18.3682000              0.2753860',
#  '4.5913040              0.8434770',
#  '1  d',
#  '1.0902030              1.0000000',
#  '}',
#  'Ga:3-21G',
#  '{',
#  '3  s',
#  '4751.8979000              0.0628400',
#  '718.9205400              0.3736110',
#  '157.4459200              0.6843630',
#  '3  s',
#  '209.5834000             -0.1115160',
#  '45.6917100              0.0926960',
#  '14.1329700              0.9622870',
#  '3  s',
#  '14.5995400              0.2910290',
#  '4.8608420             -0.3231880',
#  '1.5491110             -0.8643910',
#  '2  s',
#  '1.2679430             -0.2851310',
#  '0.1883990              1.1280220',
#  '1  s',
#  '0.0572370              1.0000000',
#  '3  p',
#  '209.5834000              0.1442660',
#  '45.6917100              0.5731780',
#  '14.1329700              0.4490860',
#  '3  p',
#  '14.5995400              0.0265620',
#  '4.8608420              0.4833140',
#  '1.5491110              0.5924300',
#  '2  p',
#  '1.2679430              0.0301830',
#  '0.1883990              0.9884660',
#  '1  p',
#  '0.0572370              1.0000000',
#  '3  d',
#  '21.2925300              0.1619900',
#  '5.3931660              0.5116740',
#  '1.3338830              0.5898730',
#  '}',
#  'Ge:3-21G',
#  '{',
#  '3  s',
#  '5073.7499000              0.0627250',
#  '767.7241700              0.3731670',
#  '168.1888100              0.6847870',
#  '3  s',
#  '224.4360000             -0.1115150',
#  '48.9554300              0.0912000',
#  '15.1837000              0.9634490',
#  '3  s',
#  '15.9125700             -0.2895650',
#  '5.4414370              0.2938830',
#  '1.7426030              0.8891990',
#  '2  s',
#  '1.4665380             -0.3967340',
#  '0.2630930              1.1906700',
#  '1  s',
#  '0.0848210              1.0000000',
#  '3  p',
#  '224.4360000              0.1446400',
#  '48.9554300              0.5753800',
#  '15.1837000              0.4459950',
#  '3  p',
#  '15.9125700              0.0229730',
#  '5.4414370              0.4732450',
#  '1.7426030              0.6032780',
#  '2  p',
#  '1.4665380              0.0278930',
#  '0.2630930              0.9874900',
#  '1  p',
#  '0.0848210              1.0000000',
#  '3  d',
#  '24.3214210              0.1577990',
#  '6.2238140              0.5114920',
#  '1.5887370              0.5857700',
#  '}',
#  'As:3-21G',
#  '{',
#  '3  s',
#  '5407.6138000              0.0626010',
#  '818.1743600              0.3727790',
#  '179.2656900              0.6851840',
#  '3  s',
#  '237.7783000             -0.1128380',
#  '54.2566200              0.0872270',
#  '16.3280300              0.9681880',
#  '3  s',
#  '17.1018500             -0.2914540',
#  '5.8051440              0.2969620',
#  '1.9020840              0.8865790',
#  '2  s',
#  '1.6754040             -0.5057610',
#  '0.3416560              1.2517640',
#  '1  s',
#  '0.1136300              1.0000000',
#  '3  p',
#  '237.7783000              0.1496800',
#  '54.2566200              0.5623220',
#  '16.3280300              0.4593230',
#  '3  p',
#  '17.1018500              0.0256860',
#  '5.8051440              0.4833970',
#  '1.9020840              0.5887850',
#  '2  p',
#  '1.6754040              0.0252820',
#  '0.3416560              0.9874330',
#  '1  p',
#  '0.1136300              1.0000000',
#  '3  d',
#  '27.4372090              0.1544950',
#  '7.0840440              0.5114320',
#  '1.8558230              0.5821940',
#  '}',
#  'Se:3-21G',
#  '{',
#  '3  s',
#  '5751.3215000              0.0624930',
#  '870.2572100              0.3723680',
#  '190.7294900              0.6855800',
#  '3  s',
#  '255.0164000             -0.1119080',
#  '55.5765400              0.0909990',
#  '17.3566100              0.9636680',
#  '3  s',
#  '18.4456800             -0.2917930',
#  '6.3287590              0.2846210',
#  '2.0967580              0.8973050',
#  '2  s',
#  '1.8726330             -0.5677640',
#  '0.4174740              1.2941270',
#  '1  s',
#  '0.1370910              1.0000000',
#  '3  p',
#  '255.0164000              0.1461490',
#  '55.5765400              0.5813710',
#  '17.3566100              0.4374600',
#  '3  p',
#  '18.4456800              0.0244210',
#  '6.3287590              0.4833650',
#  '2.0967580              0.5879040',
#  '2  p',
#  '1.8726330              0.0282550',
#  '0.4174740              0.9849060',
#  '1  p',
#  '0.1370910              1.0000000',
#  '3  d',
#  '30.6274640              0.1519860',
#  '7.9712760              0.5116400',
#  '2.1348100              0.5786940',
#  '}',
#  'Br:3-21G',
#  '{',
#  '3  s',
#  '6103.2899000              0.0624180',
#  '923.6974300              0.3720410',
#  '202.5203100              0.6858730',
#  '3  s',
#  '270.6015000             -0.1121490',
#  '58.2535700              0.0931450',
#  '18.4693300              0.9616790',
#  '3  s',
#  '19.7614200             -0.2938700',
#  '6.8217520              0.2802660',
#  '2.2916290              0.9020360',
#  '2  s',
#  '2.1312060             -0.6518030',
#  '0.4993540              1.3360120',
#  '1  s',
#  '0.1647640              1.0000000',
#  '3  p',
#  '270.6015000              0.1477510',
#  '58.2535700              0.6010560',
#  '18.4693300              0.4128700',
#  '3  p',
#  '19.7614200              0.0250070',
#  '6.8217520              0.4866100',
#  '2.2916290              0.5824230',
#  '2  p',
#  '2.1312060              0.0287080',
#  '0.4993540              0.9840700',
#  '1  p',
#  '0.1647640              1.0000000',
#  '3  d',
#  '33.9650970              0.1496670',
#  '8.9008310              0.5117480',
#  '2.4284360              0.5759150',
#  '}',
#  'Kr:3-21G',
#  '{',
#  '3  s',
#  '6446.6307000              0.0625400',
#  '976.8757000              0.3721070',
#  '214.4795500              0.6856110',
#  '3  s',
#  '287.6446000             -0.1120610',
#  '62.6200900              0.0901390',
#  '19.6917400              0.9643300',
#  '3  s',
#  '21.1232100             -0.2958170',
#  '7.3032860              0.2792170',
#  '2.4888500              0.9037300',
#  ...]

# %%
with open("periodic_table.json", "r") as f:
    periodic_table = json.load(f)

# %%
periodic_table
# Out:
# {'H': 1,
#  'He': 2,
#  'Li': 3,
#  'Be': 4,
#  'B': 5,
#  'C': 6,
#  'N': 7,
#  'O': 8,
#  'F': 9,
#  'Ne': 10,
#  'Na': 11,
#  'Mg': 12,
#  'Al': 13,
#  'Si': 14,
#  'P': 15,
#  'S': 16,
#  'Cl': 17,
#  'Ar': 18,
#  'K': 19,
#  'Ca': 20,
#  'Sc': 21,
#  'Ti': 22,
#  'V': 23,
#  'Cr': 24,
#  'Mn': 25,
#  'Fe': 26,
#  'Co': 27,
#  'Ni': 28,
#  'Cu': 29,
#  'Zn': 30,
#  'Ga': 31,
#  'Ge': 32,
#  'As': 33,
#  'Se': 34,
#  'Br': 35,
#  'Kr': 36,
#  'Rb': 37,
#  'Sr': 38,
#  'Y': 39,
#  'Zr': 40,
#  'Nb': 41,
#  'Mo': 42,
#  'Tc': 43,
#  'Ru': 44,
#  'Rh': 45,
#  'Pd': 46,
#  'Ag': 47,
#  'Cd': 48,
#  'In': 49,
#  'Sn': 50,
#  'Sb': 51,
#  'Te': 52,
#  'I': 53,
#  'Xe': 54,
#  'Cs': 55,
#  'Ba': 56,
#  'La': 57,
#  'Ce': 58,
#  'Pr': 59,
#  'Nd': 60,
#  'Pm': 61,
#  'Sm': 62,
#  'Eu': 63,
#  'Gd': 64,
#  'Tb': 65,
#  'Dy': 66,
#  'Ho': 67,
#  'Er': 68,
#  'Tm': 69,
#  'Yb': 70,
#  'Lu': 71,
#  'Hf': 72,
#  'Ta': 73,
#  'W': 74,
#  'Re': 75,
#  'Os': 76,
#  'Ir': 77,
#  'Pt': 78,
#  'Au': 79,
#  'Hg': 80,
#  'Tl': 81,
#  'Pb': 82,
#  'Bi': 83,
#  'Po': 84,
#  'At': 85,
#  'Rn': 86,
#  'Fr': 87,
#  'Ra': 88,
#  'Ac': 89,
#  'Th': 90,
#  'Pa': 91,
#  'U': 92,
#  'Np': 93,
#  'Pu': 94,
#  'Am': 95,
#  'Cm': 96,
#  'Bk': 97,
#  'Cf': 98,
#  'Es': 99,
#  'Fm': 100,
#  'Md': 101,
#  'No': 102,
#  'Lr': 103,
#  'Rf': 104,
#  'Db': 105,
#  'Sg': 106,
#  'Bh': 107,
#  'Hs': 108,
#  'Mt': 109,
#  'Ds': 110,
#  'Rg': 111,
#  'Cn': 112,
#  'Nh': 113,
#  'Fl': 114,
#  'Mc': 115,
#  'Lv': 116,
#  'Ts': 117,
#  'Og': 118,
#  'Uue': 119}

# %%
with open("bipy.xyz", "r") as f:
    bpy = f.readlines()

atoms = set()
for i in bpy:
    if (atom := i.split()[0]) in periodic_table.keys():
        atoms.add(atom)

# %%
atoms
# Out:
# {'C', 'Cu', 'F', 'H', 'N', 'O'}

# %%
atoms = {atom for i in bpy if (atom := i.split()[0]) in periodic_table.keys()}
atoms
# Out:
# {'C', 'Cu', 'F', 'H', 'N', 'O'}

# %%
matches = []
stack = []
start_index = -1

with open('basis_sets/3-21G', 'r') as f:
    file_str = f.read()

# %%
with open('basis_json/dyall-aae2z.json', 'r') as f:
    data_t = json.load(f)

# %%
data_t['elements']
# Out:
# {'1': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['8.29687389E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.24571508E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.83382422E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['8.00164139E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.58629441E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['8.99766770E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.35902587E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['5.02448897E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.14691054E-01'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a',
#      'dyall2012b',
#      'dyall2023a',
#      'dyall2023b']}]},
#  '2': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.34522333E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.52200252E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['7.99840299E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.21385929E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.67371603E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.09005872E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['5.97344735E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.27228449E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.90416896E-01'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a',
#      'dyall2012b',
#      'dyall2023a',
#      'dyall2023b']}]},
#  '3': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.35511989E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['5.01233011E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.13838273E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.21730657E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.04340051E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.68402247E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.36667189E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['5.17762820E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['7.44368272E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.82023810E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['7.55154907E-03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['6.25548696E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.37071123E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.67290922E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.19202868E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['4.47386748E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.79497017E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['4.52550008E-03'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a',
#      'dyall2012b',
#      'dyall2023a',
#      'dyall2023b']}]},
#  '4': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.40943779E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['9.54789411E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.16522522E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.11703084E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.98836699E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['7.08885657E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.68769158E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.04861275E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.80904262E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['5.86686838E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.69265143E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.31800101E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.96193922E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['8.48448593E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.84445860E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.02251455E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.74948730E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['9.95519767E-03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['2.71217265E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['6.90653847E-02'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a',
#      'dyall2012b',
#      'dyall2023a',
#      'dyall2023b']}]},
#  '5': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['9.31890933E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.38381575E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.13231718E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['8.83973383E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.87378723E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.02925898E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.97389889E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.61011130E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.27059892E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.02704305E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.96312407E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.25301829E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['5.11445067E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.50095842E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['5.09574383E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.81570551E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['6.48912221E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.72291541E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['3.46511210E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['8.82389623E-02'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a', 'dyall2012b', 'dyall2023b']}]},
#  '6': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['8.42995851E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.25053402E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.82743110E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['7.96080882E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.56825450E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['9.02650296E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.32774491E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['9.06582082E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.65254808E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.28879080E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['4.20847835E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.40303695E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['7.77836858E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.32153370E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['7.93710219E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.79198301E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['9.60203767E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.84450359E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['5.52361971E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.45443262E-01'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a', 'dyall2012b', 'dyall2023b']}]},
#  '7': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.18811750E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.75538845E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.95938764E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.11307086E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.58959691E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.26367612E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['4.66951503E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.29793688E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['5.15279750E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.79915698E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['5.72423049E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['4.76179541E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.09319427E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.29673806E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.12932532E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.93173563E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.31750516E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['4.00347301E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['8.26922465E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['2.25482421E-01'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a', 'dyall2012b', 'dyall2023b']}]},
#  '8': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.59925081E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.35199842E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['5.29060079E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.48462548E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['4.78417313E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.68559662E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.23711537E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.75808802E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.90688830E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.39078229E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['7.37104770E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['6.33409745E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.45830479E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['4.42797374E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.51782600E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['5.24175730E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.72133105E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['5.24505855E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.17766132E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['3.30124445E-01'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a', 'dyall2012b', 'dyall2023b']}]},
#  '9': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.08122193E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.04524252E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.82912687E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.91245323E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.15619638E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.16954416E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['8.03372746E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.28806696E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['8.91891561E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.06490573E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['9.14278738E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['8.12382078E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.87382214E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['5.71665823E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.95959041E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['6.72331544E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.17227007E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['6.58062230E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.61811961E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['4.59945026E-01'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a', 'dyall2012b', 'dyall2023b']}]},
#  '10': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.63937466E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.84039579E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['8.58347380E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.39831047E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['7.70985719E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.71659873E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.00621973E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.88859221E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.11904975E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.82176942E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.13403907E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.01356529E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.34055004E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['7.16482787E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.45525847E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['8.37825292E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.67057270E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['8.25626434E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['2.16640868E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['6.40817214E-01'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a', 'dyall2012b', 'dyall2023b']}]},
#  '11': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.67792806E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['5.30926008E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.18110639E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.29023939E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.05644880E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.72817927E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.39450756E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['4.79319847E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.75439259E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.05162152E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.36878648E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['5.63828723E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.32237456E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.47741784E-03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.51036063E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.50295268E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.08283663E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.79319715E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.35313127E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['4.65632696E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.82262627E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['6.51878594E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.05385167E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['4.93760548E-03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['2.96645265E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['5.77612840E-01'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a',
#      'dyall2012b',
#      'dyall2023a',
#      'dyall2023b']}]},
#  '12': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.04215416E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['8.61269535E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.90202674E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['5.27577646E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.69320161E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.01840839E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.31731851E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['9.45704001E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.63556906E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['8.99737371E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.49554207E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.07697801E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['4.01639940E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.34309914E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.07387988E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['4.81457930E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.49657424E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['5.30731907E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.94280859E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['6.97272353E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.70895143E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.30355053E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.89852331E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['9.18259110E-03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['3.88167943E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['8.64065990E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.96440169E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['5.36156252E-02'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a',
#      'dyall2012b',
#      'dyall2023a',
#      'dyall2023b']}]},
#  '13': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['8.22157890E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.15957649E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.54453086E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['7.02795217E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.24966679E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['7.99049065E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.07705104E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.24983416E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.36586330E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.18932643E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.75866307E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.51081752E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.17724199E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.70038076E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['6.26443560E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.95414963E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['6.98745273E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.60395194E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['9.65061208E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.11056456E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['6.00913311E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.41539264E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['4.59260115E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['9.60503944E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.93201508E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['5.27316775E-02'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a', 'dyall2012b', 'dyall2023b']}]},
#  '14': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.04052681E+05'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.45312628E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.16940829E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['8.71719057E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.78191231E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['9.85902809E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.78633488E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.52888958E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['4.12846838E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.50246568E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.53084395E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['9.29886769E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.13172058E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.30667196E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['7.65812543E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.39331074E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['8.59974926E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.24463955E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.23477396E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.95467725E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['8.50710464E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.24201687E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['5.69343938E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.27082421E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['2.73978756E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['8.00180146E-02'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a', 'dyall2012b', 'dyall2023b']}]},
#  '15': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.27817378E+05'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.76768640E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.83218251E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.04954834E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.33885131E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.18038894E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['4.52126521E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.81818021E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['4.94970020E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.84448181E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.39615003E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.23961699E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['4.09756058E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.85869276E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['8.91826403E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.78899440E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.00455314E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.82167337E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.48745844E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.87903897E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.12515635E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.05818876E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['6.91044365E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.62994079E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['3.69960709E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.13423367E-01'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a', 'dyall2012b', 'dyall2023b']}]},
#  '16': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.54184920E+05'],
#     'coefficients': [['1.0']]},
# ...
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['6.88645118E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['3.63215132E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.95080977E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.02633964E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['5.29989718E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['2.64229268E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.24755275E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['5.46674430E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['2.07169726E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['8.19822830E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['1.55874574E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['5.16482517E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['2.16090441E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['1.00375884E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['4.91918626E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['2.47415547E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['1.24172009E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['6.07887380E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['2.84454763E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['1.19184727E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['3.56439300E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [4],
#     'exponents': ['4.65156190E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [4],
#     'exponents': ['6.78364000E+00'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a', 'dyall2012b', 'dyall2023b']}]},
#  '118': {'electron_shells': [{'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['5.24543434E+07'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.39342753E+07'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['4.72586931E+06'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.76655977E+06'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['7.20004310E+05'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.08342403E+05'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.37804335E+05'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.32550050E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.96875536E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.41569741E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.84986815E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.36021593E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.67684236E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['8.47152669E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['4.39087321E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.32521218E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.25971789E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['6.93405284E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['3.54206791E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.02418111E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.00527536E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['5.56202638E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['2.35158724E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.21100065E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['4.12227893E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['1.59031719E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [0],
#     'exponents': ['4.35402970E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['4.56226785E+07'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.28729373E+07'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.93590515E+06'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.28310998E+06'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['4.39439154E+05'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.56830707E+05'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['5.80943914E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.23217925E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['8.92013696E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.72283531E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.62573603E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['7.41242740E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.50951511E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.69104303E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['8.47054959E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['4.13905180E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.14933937E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['1.02679675E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['5.18229819E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.19602479E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['9.89384744E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['3.19468837E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['9.86706817E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto',
#     'region': '',
#     'angular_momentum': [1],
#     'exponents': ['2.70144270E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['9.34050542E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['2.17092956E+04'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['6.92742965E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['2.64817876E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.14081718E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['5.33672197E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['2.64430103E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.36373690E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['7.18993191E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['3.79447993E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['2.04023819E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.07633686E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['5.57883329E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['2.80009817E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['1.33179571E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['5.88745938E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['2.23304938E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [2],
#     'exponents': ['8.78787900E-02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['1.62557486E+03'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['5.37987566E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['2.25026762E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['1.04559255E+02'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['5.13069042E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['2.58520536E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['1.30188065E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['6.40298978E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['3.01668444E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['1.27846072E+00'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [3],
#     'exponents': ['3.94295680E-01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [4],
#     'exponents': ['4.77113820E+01'],
#     'coefficients': [['1.0']]},
#    {'function_type': 'gto_spherical',
#     'region': '',
#     'angular_momentum': [4],
#     'exponents': ['7.06521160E+00'],
#     'coefficients': [['1.0']]}],
#   'references': [{'reference_description': "Dyall's augmented all-electron 2-zeta primitive basis set",
#     'reference_keys': ['dyall2012a', 'dyall2012b', 'dyall2023b']}]}}

# %%
from typing import Union

angular_momentum_dict = {
    's': 0,
    'p': 1,
    'd': 2,
    'f': 3,
    'g': 4,
    'h': 5,
}

@dataclass
class Shell:
    def __init__(self, angular_momentum: int, matrix: np.ndarray):
        self.exponents = np.ndarray
        self.coefficients = []
        self.function_type = "gto"
        self.region = "valence"
        self.angular_momentum = angular_momentum
        self.parse_matrix(matrix)

    def parse_matrix(self, matrix: np.ndarray):
        self.exponents = matrix[:, 0].tolist()
        self.coefficients = matrix[:, 1].tolist()

    def as_dict(self):
        retdict = {
            "function_type": self.function_type,
            "region": self.region,
            "angular_momentum": [self.angular_momentum],
            "exponents": self.exponents,
            "coefficients": [self.coefficients]
        }
        return retdict

    def __repr__(self):
        return f"{self.as_dict()}"

@dataclass()
class Basis:
    def __init__(self):
        self.elements = {}

    def parse_json(self, json_str: str):
        data = json.loads(json_str)
        for atom in data["elements"]:
            self.elements[atom] = {}
            for shell in data["elements"][atom]["electron_shells"]:
                self.add_shell(atom, shell)

    def add_shell(self, atom: int, shell: dict):
        atom = str(atom)
        if not atom in self.elements:
            self.elements[atom] = dict()
        if not "electron_shells" in self.elements[atom]:
            self.elements[atom]["electron_shells"] = []
        skey = list(shell.keys())[0]
        angular_momentum = angular_momentum_dict[skey]
        self.elements[f"{atom}"]["electron_shells"].append(Shell(angular_momentum, shell[skey]).as_dict())

    def add_element(self, atom: Union[str, int], shells: list):
        if atom is str:
            atom = str(periodic_table[atom])
        atom = str(atom)
        for i in shells:
            self.add_shell(atom, i)

    def as_dict(self):
        return {
            "molssi_bse_schema": {
                "schema_type": "complete",
                "schema_version": "0.1"
            },
            "elements": {
                atom: self.elements[atom] for atom in self.elements
            }
        }

def to_dict(file_str: str) -> dict:
    def find_match():
        stack = []
        matches = []
        for index, char in enumerate(file_str):
            if char == '{':
                stack.append(index)
            elif char == '}' and stack:
                start = stack.pop()
                matches.append((start, index))
        return matches

    def find_atoms_basis() -> list:
        atom_bl = []
        file_list = [i.strip() for i in file_str.split('\n') if i != '']
        for line in file_list:
            if line.strip().startswith('!'):
                continue
            if ':' in line:
                atom_bl.append(line)
        return atom_bl

    matches = sorted(find_match())
    labels = find_atoms_basis()
    ret = dict()
    basis_obj = Basis()

    for k, match in enumerate(matches[3:]):
        fs = file_str[match[0] + 1:match[1]]
        spt = [i.strip() for i in fs.split("\n") if i != '']
        ckey = periodic_table[labels[k].split(":")[0]]
        ret[ckey] = []

        z = 0
        temp_list = []
        while z < len(spt):
            try:
                ln, sp = spt[z].split()
                ln = int(ln)
                if sp in ['s', 'p']:
                    shell_data = []
                    for j in range(ln):
                        if z + j + 1 < len(spt):
                            shell_data.append(spt[z + j + 1].split())
                    temp_list.append({sp: np.array(shell_data).astype(np.float64)})
                    z += ln + 1
                else:
                    z += 1
            except ValueError:
                z += 1
                continue

        ret[ckey] = temp_list
        basis_obj.add_element(ckey, temp_list)
    return ret, basis_obj

# %%
with open('basis_json/dyall-aae2z.json', 'r') as f:
    data = f.read()
tbas = Basis()
tbas.parse_json(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 4
#       2     data = f.read()
#       3 tbas = Basis()
# ----> 4 tbas.parse_json(data)
#
# Cell In[15], line 49, in Basis.parse_json(self, json_str)
#      47 self.elements[atom] = {}
#      48 for shell in data["elements"][atom]["electron_shells"]:
# ---> 49     self.add_shell(atom, shell)
#
# Cell In[15], line 58, in Basis.add_shell(self, atom, shell)
#      56     self.elements[atom]["electron_shells"] = []
#      57 skey = list(shell.keys())[0]
# ---> 58 angular_momentum = angular_momentum_dict[skey]
#      59 self.elements[f"{atom}"]["electron_shells"].append(Shell(angular_momentum, shell[skey]).as_dict())
#
# KeyError: 'function_type'

# %%
with open('basis_sets/3-21G', 'r') as f:
    matches, bc = to_dict(f.read())

# %%
bc.as_dict()
# Out:
# {'molssi_bse_schema': {'schema_type': 'complete', 'schema_version': '0.1'},
#  'elements': {'1': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [5.447178, 0.824547],
#      'coefficients': [[0.156285, 0.904691]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.183192],
#      'coefficients': [[1.0]]}]},
#   '2': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [13.6267, 1.99935],
#      'coefficients': [[0.17523, 0.893483]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.382993],
#      'coefficients': [[1.0]]}]},
#   '3': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [36.8382, 5.48172, 1.11327],
#      'coefficients': [[0.0696686, 0.381346, 0.681702]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.540205, 0.102255],
#      'coefficients': [[-0.263127, 1.14339]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.028565],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.540205, 0.102255],
#      'coefficients': [[0.161546, 0.915663]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.028565],
#      'coefficients': [[1.0]]}]},
#   '4': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [71.8876, 10.7289, 2.22205],
#      'coefficients': [[0.0644263, 0.366096, 0.695934]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.29548, 0.268881],
#      'coefficients': [[-0.421064, 1.22407]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.07735],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.29548, 0.268881],
#      'coefficients': [[0.205132, 0.882528]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.07735],
#      'coefficients': [[1.0]]}]},
#   '5': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [116.434, 17.4314, 3.68016],
#      'coefficients': [[0.0629605, 0.363304, 0.697255]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [2.28187, 0.465248],
#      'coefficients': [[-0.368662, 1.19944]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.124328],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [2.28187, 0.465248],
#      'coefficients': [[0.231152, 0.866764]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.124328],
#      'coefficients': [[1.0]]}]},
#   '6': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [172.256, 25.9109, 5.53335],
#      'coefficients': [[0.0617669, 0.358794, 0.700713]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [3.66498, 0.770545],
#      'coefficients': [[-0.395897, 1.21584]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.195857],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [3.66498, 0.770545],
#      'coefficients': [[0.23646, 0.860619]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.195857],
#      'coefficients': [[1.0]]}]},
#   '7': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [242.766, 36.4851, 7.81449],
#      'coefficients': [[0.0598657, 0.352955, 0.706513]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [5.42522, 1.14915],
#      'coefficients': [[-0.413301, 1.22442]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.283205],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [5.42522, 1.14915],
#      'coefficients': [[0.237972, 0.858953]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.283205],
#      'coefficients': [[1.0]]}]},
#   '8': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [322.037, 48.4308, 10.4206],
#      'coefficients': [[0.0592394, 0.3515, 0.707658]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [7.40294, 1.5762],
#      'coefficients': [[-0.404453, 1.22156]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.373684],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [7.40294, 1.5762],
#      'coefficients': [[0.244586, 0.853955]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.373684],
#      'coefficients': [[1.0]]}]},
#   '9': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [413.801, 62.2446, 13.434],
#      'coefficients': [[0.0585483, 0.349308, 0.709632]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [9.77759, 2.08617],
#      'coefficients': [[-0.407327, 1.22314]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.482383],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [9.77759, 2.08617],
#      'coefficients': [[0.24668, 0.852321]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.482383],
#      'coefficients': [[1.0]]}]},
#   '10': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [515.724, 77.6538, 16.8136],
#      'coefficients': [[0.058143, 0.347951, 0.710714]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [12.483, 2.66451],
#      'coefficients': [[-0.409922, 1.22431]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.60625],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [12.483, 2.66451],
#      'coefficients': [[0.24746, 0.851743]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.60625],
#      'coefficients': [[1.0]]}]},
#   '11': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [547.613, 82.0678, 17.6917],
#      'coefficients': [[0.0674911, 0.393505, 0.665605]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [17.5407, 3.79398, 0.906441],
#      'coefficients': [[-0.111937, 0.254654, 0.844417]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.501824, 0.0609458],
#      'coefficients': [[-0.21966, 1.08912]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.0244349],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [17.5407, 3.79398, 0.906441],
#      'coefficients': [[0.128233, 0.471533, 0.604273]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.501824, 0.0609458],
#      'coefficients': [[0.0090665, 0.997202]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.0244349],
#      'coefficients': [[1.0]]}]},
#   '12': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [652.841, 98.3805, 21.2996],
#      'coefficients': [[0.0675982, 0.391778, 0.666661]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [23.3727, 5.19953, 1.31508],
#      'coefficients': [[-0.110246, 0.184119, 0.896399]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.611349, 0.141841],
#      'coefficients': [[-0.361101, 1.21505]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.0464011],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [23.3727, 5.19953, 1.31508],
#      'coefficients': [[0.121014, 0.46281, 0.606907]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.611349, 0.141841],
#      'coefficients': [[0.0242633, 0.986673]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.0464011],
#      'coefficients': [[1.0]]}]},
#   '13': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [775.737, 116.952, 25.3326],
#      'coefficients': [[0.0668347, 0.389061, 0.669468]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [29.4796, 6.63314, 1.72675],
#      'coefficients': [[-0.107902, 0.146245, 0.92373]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.94616, 0.202506],
#      'coefficients': [[-0.320327, 1.18412]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.0639088],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [29.4796, 6.63314, 1.72675],
#      'coefficients': [[0.117574, 0.461174, 0.605535]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.94616, 0.202506],
#      'coefficients': [[0.0519383, 0.97266]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.0639088],
#      'coefficients': [[1.0]]}]},
#   '14': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [910.655, 137.336, 29.7601],
#      'coefficients': [[0.0660823, 0.386229, 0.67238]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [36.6716, 8.31729, 2.21645],
#      'coefficients': [[-0.104511, 0.10741, 0.951446]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.07913, 0.302422],
#      'coefficients': [[-0.376108, 1.25165]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.0933392],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [36.6716, 8.31729, 2.21645],
#      'coefficients': [[0.113355, 0.457578, 0.607427]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.07913, 0.302422],
#      'coefficients': [[0.067103, 0.956883]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.0933392],
#      'coefficients': [[1.0]]}]},
#   '15': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1054.9, 159.195, 34.5304],
#      'coefficients': [[0.065541, 0.384036, 0.674541]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [44.2866, 10.1019, 2.73997],
#      'coefficients': [[-0.10213, 0.081592, 0.969788]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.21865, 0.395546],
#      'coefficients': [[-0.371495, 1.27099]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.122811],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [44.2866, 10.1019, 2.73997],
#      'coefficients': [[0.110851, 0.456495, 0.606936]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.21865, 0.395546],
#      'coefficients': [[0.091582, 0.934924]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.122811],
#      'coefficients': [[1.0]]}]},
#   '16': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1210.62, 182.747, 39.6673],
#      'coefficients': [[0.065007, 0.38204, 0.676545]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [52.2236, 11.9629, 3.28911],
#      'coefficients': [[-0.10031, 0.065088, 0.981455]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.22384, 0.457303],
#      'coefficients': [[-0.286089, 1.22806]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.142269],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [52.2236, 11.9629, 3.28911],
#      'coefficients': [[0.109646, 0.457649, 0.604261]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.22384, 0.457303],
#      'coefficients': [[0.164777, 0.870855]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.142269],
#      'coefficients': [[1.0]]}]},
#   '17': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1376.4, 207.857, 45.1554],
#      'coefficients': [[0.0645827, 0.380363, 0.67819]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [60.8014, 13.9765, 3.8871],
#      'coefficients': [[-0.0987639, 0.0511338, 0.991337]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.35299, 0.526955],
#      'coefficients': [[-0.222401, 1.18252]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.166714],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [60.8014, 13.9765, 3.8871],
#      'coefficients': [[0.108598, 0.458682, 0.601962]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.35299, 0.526955],
#      'coefficients': [[0.219216, 0.822321]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.166714],
#      'coefficients': [[1.0]]}]},
#   '18': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1553.71, 234.678, 51.0121],
#      'coefficients': [[0.0641707, 0.378797, 0.679752]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [70.0453, 16.1473, 4.53492],
#      'coefficients': [[-0.0974661, 0.0390569, 0.999916]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.54209, 0.607267],
#      'coefficients': [[-0.176866, 1.1469]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.195373],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [70.0453, 16.1473, 4.53492],
#      'coefficients': [[0.107619, 0.459576, 0.600041]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.54209, 0.607267],
#      'coefficients': [[0.255687, 0.789842]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.195373],
#      'coefficients': [[1.0]]}]},
#   '19': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1721.1755, 260.01633, 56.624554],
#      'coefficients': [[0.0648747, 0.3808593, 0.6773681]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [71.5572, 15.43894, 4.474551],
#      'coefficients': [[-0.1093429, 0.113064, 0.9462575]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [4.121275, 1.188621, 0.375674],
#      'coefficients': [[-0.269973, 0.3646323, 0.8107533]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.244577, 0.038972],
#      'coefficients': [[-0.268825, 1.128983]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.016063],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [71.5572, 15.43894, 4.474551],
#      'coefficients': [[0.1339654, 0.5302673, 0.5117992]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [4.121275, 1.188621, 0.375674],
#      'coefficients': [[0.01994922, 0.4340213, 0.6453226]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.244577, 0.038972],
#      'coefficients': [[0.0003081035, 0.9998787]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.016063],
#      'coefficients': [[1.0]]}]},
#   '20': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1915.4348, 289.53324, 63.106352],
#      'coefficients': [[0.064624, 0.379838, 0.678329]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [80.39744, 17.33075, 5.083624],
#      'coefficients': [[-0.109303, 0.1089, 0.949277]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [4.782229, 1.462558, 0.479223],
#      'coefficients': [[-0.281607, 0.341051, 0.838104]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.439682, 0.05913],
#      'coefficients': [[-0.269705, 1.113293]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.023897],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [80.39744, 17.33075, 5.083624],
#      'coefficients': [[0.135433, 0.537222, 0.501804]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [4.782229, 1.462558, 0.479223],
#      'coefficients': [[0.019009, 0.436038, 0.638671]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.439682, 0.05913],
#      'coefficients': [[0.000308, 0.999896]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.023897],
#      'coefficients': [[1.0]]}]},
#   '21': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [2119.887, 320.4299, 69.89893],
#      'coefficients': [[0.064421, 0.37916, 0.678963]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [89.7645, 19.3851, 5.731423],
#      'coefficients': [[-0.109384, 0.10507, 0.952205]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [5.491938, 1.743742, 0.566227],
#      'coefficients': [[-0.285211, 0.324155, 0.856592]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.516802, 0.067214],
#      'coefficients': [[-0.262678, 1.108079]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.025985],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [89.7645, 19.3851, 5.731423],
#      'coefficients': [[0.136328, 0.54186, 0.495055]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [5.491938, 1.743742, 0.566227],
#      'coefficients': [[0.017614, 0.433645, 0.642551]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.516802, 0.067214],
#      'coefficients': [[0.000327, 0.999893]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.025985],
#      'coefficients': [[1.0]]}]},
#   '22': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [2335.02, 353.0441, 77.05845],
#      'coefficients': [[0.064217, 0.378412, 0.679681]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [99.57387, 21.54671, 6.413965],
#      'coefficients': [[-0.109472, 0.101943, 0.954622]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [6.238279, 1.996108, 0.64649],
#      'coefficients': [[-0.286137, 0.321828, 0.859551]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.573285, 0.073119],
#      'coefficients': [[-0.24245, 1.100075]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.026538],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [99.57387, 21.54671, 6.413965],
#      'coefficients': [[0.137297, 0.545875, 0.489068]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [6.238279, 1.996108, 0.64649],
#      'coefficients': [[0.019237, 0.440442, 0.63562]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.573285, 0.073119],
#      'coefficients': [[0.000292, 0.999907]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.026538],
#      'coefficients': [[1.0]]}]},
#   '23': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [2563.877, 387.534, 84.59823],
#      'coefficients': [[0.063948, 0.377594, 0.680542]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [109.7938, 23.76921, 7.122961],
#      'coefficients': [[-0.109836, 0.100707, 0.955633]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [6.981204, 2.219839, 0.719803],
#      'coefficients': [[-0.288459, 0.336436, 0.84819]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.631262, 0.080062],
#      'coefficients': [[-0.23649, 1.097721]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.028865],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [109.7938, 23.76921, 7.122961],
#      'coefficients': [[0.138421, 0.550489, 0.482417]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [6.981204, 2.219839, 0.719803],
#      'coefficients': [[0.021821, 0.456762, 0.618675]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.631262, 0.080062],
#      'coefficients': [[0.00019, 0.99994]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.028865],
#      'coefficients': [[1.0]]}]},
#   '24': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [2798.294, 423.137, 92.43886],
#      'coefficients': [[0.063824, 0.377084, 0.680989]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [120.2806, 26.03727, 7.844172],
#      'coefficients': [[-0.117779, 0.101431, 0.957198]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [7.793276, 2.497196, 0.805142],
#      'coefficients': [[-0.288857, 0.335115, 0.850248]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.703921, 0.086162],
#      'coefficients': [[-0.232251, 1.093671]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.032199],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [120.2806, 26.03727, 7.844172],
#      'coefficients': [[0.139878, 0.555983, 0.474818]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [7.793276, 2.497196, 0.805142],
#      'coefficients': [[0.022185, 0.461625, 0.614539]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.703921, 0.086162],
#      'coefficients': [[0.00018, 0.999945]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.032199],
#      'coefficients': [[1.0]]}]},
#   '25': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [3041.686, 460.0901, 100.5958],
#      'coefficients': [[0.063745, 0.376749, 0.681247]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [131.7673, 28.56915, 8.660501],
#      'coefficients': [[-0.110296, 0.09819, 0.957659]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [8.569081, 2.768178, 0.887288],
#      'coefficients': [[-0.291714, 0.343963, 0.845198]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.767443, 0.092025],
#      'coefficients': [[-0.230004, 1.09145]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.033265],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [131.7673, 28.56915, 8.660501],
#      'coefficients': [[0.140454, 0.557802, 0.471501]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [8.569081, 2.768178, 0.887288],
#      'coefficients': [[0.024224, 0.46866, 0.607421]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.767443, 0.092025],
#      'coefficients': [[0.000308, 0.999907]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.033265],
#      'coefficients': [[1.0]]}]},
#   '26': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [3299.184, 499.0886, 109.1614],
#      'coefficients': [[0.063586, 0.376202, 0.681785]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [143.4652, 31.16858, 9.483612],
#      'coefficients': [[-0.110552, 0.096847, 0.958797]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [9.464565, 3.100373, 0.986493],
#      'coefficients': [[-0.292056, 0.337524, 0.851942]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.853412, 0.098812],
#      'coefficients': [[-0.227944, 1.088287]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.036442],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [143.4652, 31.16858, 9.483612],
#      'coefficients': [[0.141101, 0.560387, 0.467644]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [9.464565, 3.100373, 0.986493],
#      'coefficients': [[0.023762, 0.468911, 0.608311]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.853412, 0.098812],
#      'coefficients': [[-0.000426, 1.000124]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.036442],
#      'coefficients': [[1.0]]}]},
#   '27': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [3564.762, 539.3908, 118.0449],
#      'coefficients': [[0.063487, 0.375818, 0.682122]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [155.4382, 33.81561, 10.33323],
#      'coefficients': [[-0.110987, 0.096767, 0.958992]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [10.38152, 3.382714, 1.076954],
#      'coefficients': [[-0.292262, 0.343251, 0.846963]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.909015, 0.105041],
#      'coefficients': [[-0.21746, 1.084998]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.037257],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [155.4382, 33.81561, 10.33323],
#      'coefficients': [[0.142064, 0.563444, 0.463024]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [10.38152, 3.382714, 1.076954],
#      'coefficients': [[0.026313, 0.476917, 0.599154]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.909015, 0.105041],
#      'coefficients': [[0.000228, 0.999934]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.037257],
#      'coefficients': [[1.0]]}]},
#   '28': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [3848.005, 582.0307, 127.3674],
#      'coefficients': [[0.063266, 0.375171, 0.682824]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [168.2896, 36.65633, 11.23212],
#      'coefficients': [[-0.111115, 0.095324, 0.960161]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [11.35877, 3.738846, 1.182463],
#      'coefficients': [[-0.29206, 0.337541, 0.852533]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.988904, 0.111025],
#      'coefficients': [[-0.213687, 1.081933]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.039258],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [168.2896, 36.65633, 11.23212],
#      'coefficients': [[0.14249, 0.565547, 0.459993]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [11.35877, 3.738846, 1.182463],
#      'coefficients': [[0.026138, 0.476598, 0.60038]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.988904, 0.111025],
#      'coefficients': [[0.000294, 0.999917]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.039258],
#      'coefficients': [[1.0]]}]},
#   '29': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [4134.302, 625.4912, 136.9556],
#      'coefficients': [[0.063188, 0.374845, 0.6831]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [181.496, 39.57431, 12.16246],
#      'coefficients': [[-0.11132, 0.094487, 0.960879]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [12.35111, 4.049651, 1.279225],
#      'coefficients': [[-0.292223, 0.342991, 0.847946]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.049804, 0.116933],
#      'coefficients': [[-0.206508, 1.079273]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.000751],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [181.496, 39.57431, 12.16246],
#      'coefficients': [[0.143084, 0.567756, 0.456714]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [12.35111, 4.049651, 1.279225],
#      'coefficients': [[0.027727, 0.483524, 0.592978]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.049804, 0.116933],
#      'coefficients': [[0.000139, 0.999961]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.000751],
#      'coefficients': [[1.0]]}]},
#   '30': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [4432.288, 670.6601, 146.9024],
#      'coefficients': [[0.063093, 0.374504, 0.683416]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [195.0042, 42.56889, 13.12143],
#      'coefficients': [[-0.111628, 0.094336, 0.9611]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [13.40231, 4.399906, 1.385148],
#      'coefficients': [[-0.291781, 0.342614, 0.848284]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.121558, 0.122944],
#      'coefficients': [[-0.202371, 1.077035]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.042193],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [195.0042, 42.56889, 13.12143],
#      'coefficients': [[0.143806, 0.570002, 0.453312]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [13.40231, 4.399906, 1.385148],
#      'coefficients': [[0.028705, 0.486252, 0.590235]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.121558, 0.122944],
#      'coefficients': [[0.000344, 0.999905]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.042193],
#      'coefficients': [[1.0]]}]},
#   '31': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [4751.8979, 718.92054, 157.44592],
#      'coefficients': [[0.06284, 0.373611, 0.684363]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [209.5834, 45.69171, 14.13297],
#      'coefficients': [[-0.111516, 0.092696, 0.962287]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [14.59954, 4.860842, 1.549111],
#      'coefficients': [[0.291029, -0.323188, -0.864391]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.267943, 0.188399],
#      'coefficients': [[-0.285131, 1.128022]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.057237],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [209.5834, 45.69171, 14.13297],
#      'coefficients': [[0.144266, 0.573178, 0.449086]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [14.59954, 4.860842, 1.549111],
#      'coefficients': [[0.026562, 0.483314, 0.59243]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.267943, 0.188399],
#      'coefficients': [[0.030183, 0.988466]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.057237],
#      'coefficients': [[1.0]]}]},
#   '32': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [5073.7499, 767.72417, 168.18881],
#      'coefficients': [[0.062725, 0.373167, 0.684787]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [224.436, 48.95543, 15.1837],
#      'coefficients': [[-0.111515, 0.0912, 0.963449]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [15.91257, 5.441437, 1.742603],
#      'coefficients': [[-0.289565, 0.293883, 0.889199]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.466538, 0.263093],
#      'coefficients': [[-0.396734, 1.19067]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.084821],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [224.436, 48.95543, 15.1837],
#      'coefficients': [[0.14464, 0.57538, 0.445995]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [15.91257, 5.441437, 1.742603],
#      'coefficients': [[0.022973, 0.473245, 0.603278]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.466538, 0.263093],
#      'coefficients': [[0.027893, 0.98749]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.084821],
#      'coefficients': [[1.0]]}]},
#   '33': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [5407.6138, 818.17436, 179.26569],
#      'coefficients': [[0.062601, 0.372779, 0.685184]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [237.7783, 54.25662, 16.32803],
#      'coefficients': [[-0.112838, 0.087227, 0.968188]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [17.10185, 5.805144, 1.902084],
#      'coefficients': [[-0.291454, 0.296962, 0.886579]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.675404, 0.341656],
#      'coefficients': [[-0.505761, 1.251764]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.11363],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [237.7783, 54.25662, 16.32803],
#      'coefficients': [[0.14968, 0.562322, 0.459323]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [17.10185, 5.805144, 1.902084],
#      'coefficients': [[0.025686, 0.483397, 0.588785]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.675404, 0.341656],
#      'coefficients': [[0.025282, 0.987433]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.11363],
#      'coefficients': [[1.0]]}]},
#   '34': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [5751.3215, 870.25721, 190.72949],
#      'coefficients': [[0.062493, 0.372368, 0.68558]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [255.0164, 55.57654, 17.35661],
#      'coefficients': [[-0.111908, 0.090999, 0.963668]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [18.44568, 6.328759, 2.096758],
#      'coefficients': [[-0.291793, 0.284621, 0.897305]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.872633, 0.417474],
#      'coefficients': [[-0.567764, 1.294127]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.137091],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [255.0164, 55.57654, 17.35661],
#      'coefficients': [[0.146149, 0.581371, 0.43746]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [18.44568, 6.328759, 2.096758],
#      'coefficients': [[0.024421, 0.483365, 0.587904]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.872633, 0.417474],
#      'coefficients': [[0.028255, 0.984906]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.137091],
#      'coefficients': [[1.0]]}]},
#   '35': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [6103.2899, 923.69743, 202.52031],
#      'coefficients': [[0.062418, 0.372041, 0.685873]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [270.6015, 58.25357, 18.46933],
#      'coefficients': [[-0.112149, 0.093145, 0.961679]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [19.76142, 6.821752, 2.291629],
#      'coefficients': [[-0.29387, 0.280266, 0.902036]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [2.131206, 0.499354],
#      'coefficients': [[-0.651803, 1.336012]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.164764],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [270.6015, 58.25357, 18.46933],
#      'coefficients': [[0.147751, 0.601056, 0.41287]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [19.76142, 6.821752, 2.291629],
#      'coefficients': [[0.025007, 0.48661, 0.582423]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [2.131206, 0.499354],
#      'coefficients': [[0.028708, 0.98407]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.164764],
#      'coefficients': [[1.0]]}]},
#   '36': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [6446.6307, 976.8757, 214.47955],
#      'coefficients': [[0.06254, 0.372107, 0.685611]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [287.6446, 62.62009, 19.69174],
#      'coefficients': [[-0.112061, 0.090139, 0.96433]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [21.12321, 7.303286, 2.48885],
#      'coefficients': [[-0.295817, 0.279217, 0.90373]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [2.361374, 0.586016],
#      'coefficients': [[-0.720245, 1.376846]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.194447],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [287.6446, 62.62009, 19.69174],
#      'coefficients': [[0.147528, 0.586892, 0.429507]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [21.12321, 7.303286, 2.48885],
#      'coefficients': [[0.02607, 0.49225, 0.574274]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [2.361374, 0.586016],
#      'coefficients': [[0.028775, 0.983339]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.194447],
#      'coefficients': [[1.0]]}]},
#   '37': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [6816.7225, 1033.0007, 226.90861],
#      'coefficients': [[0.062496, 0.37195, 0.685729]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [304.1283, 66.26058, 20.91945],
#      'coefficients': [[-0.11233, 0.090751, 0.963941]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [22.46533, 7.877468, 2.705271],
#      'coefficients': [[-0.300485, 0.278357, 0.90761]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [2.692116, 0.723056, 0.259838],
#      'coefficients': [[-0.331162, 0.509699, 0.698246]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.189714, 0.033997],
#      'coefficients': [[-0.271193, 1.14155]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.014712],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [304.1283, 66.26058, 20.91945],
#      'coefficients': [[0.148441, 0.589125, 0.425825]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [22.46533, 7.877468, 2.705271],
#      'coefficients': [[0.024454, 0.494454, 0.571857]]},
#     {'function_type': 'gto',
#      'region': 'valence',
# ...
#      'coefficients': [[-0.112592, 0.08327, 0.969798]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [33.01548, 29.54543, 6.278508],
#      'coefficients': [[-1.406471, 1.218156, 1.05552]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [6.150596, 2.259746, 0.841426],
#      'coefficients': [[-0.422921, 0.498771, 0.785076]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.949069, 0.101488],
#      'coefficients': [[-0.221555, 1.080944]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.035987],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [527.6004, 114.8329, 36.95829],
#      'coefficients': [[0.151805, 0.60776, 0.399963]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [33.01548, 29.54543, 6.278508],
#      'coefficients': [[-1.609024, 1.959568, 0.708027]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [6.150596, 2.259746, 0.841426],
#      'coefficients': [[0.014482, 0.518661, 0.542666]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.949069, 0.101488],
#      'coefficients': [[-0.00154, 1.000412]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.035987],
#      'coefficients': [[1.0]]}]},
#   '49': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [12214.547, 1848.9136, 406.36833],
#      'coefficients': [[0.061248, 0.367675, 0.690136]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [550.4423, 119.7744, 38.66927],
#      'coefficients': [[-0.112709, 0.083444, 0.969688]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [47.02931, 22.49642, 6.697117],
#      'coefficients': [[-0.275895, 0.059773, 1.082148]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [6.57236, 2.502158, 0.942025],
#      'coefficients': [[-0.428483, 0.463364, 0.821968]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.001221, 0.16597],
#      'coefficients': [[-0.436417, 1.189893]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.05434],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [550.4423, 119.7744, 38.66927],
#      'coefficients': [[0.15237, 0.609651, 0.397025]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [47.02931, 22.49642, 6.697117],
#      'coefficients': [[-0.140848, 0.529087, 0.662068]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [6.57236, 2.502158, 0.942025],
#      'coefficients': [[0.010913, 0.503676, 0.558181]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.001221, 0.16597],
#      'coefficients': [[0.023163, 0.990331]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.05434],
#      'coefficients': [[1.0]]}]},
#   '50': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [12741.674, 1928.4692, 423.80797],
#      'coefficients': [[0.061135, 0.367293, 0.690545]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [574.2875, 124.9537, 40.39576],
#      'coefficients': [[-0.112746, 0.082863, 0.970151]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [48.80662, 23.83588, 7.048296],
#      'coefficients': [[-0.282453, 0.066056, 1.081987]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [6.973378, 2.69304, 1.025958],
#      'coefficients': [[-0.434036, 0.461029, 0.828558]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.131463, 0.203409],
#      'coefficients': [[-0.525208, 1.229226]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.070564],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [574.2875, 124.9537, 40.39576],
#      'coefficients': [[0.15258, 0.611011, 0.395155]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [48.80662, 23.83588, 7.048296],
#      'coefficients': [[-0.150963, 0.539968, 0.660482]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [6.973378, 2.69304, 1.025958],
#      'coefficients': [[0.011951, 0.506719, 0.552911]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.131463, 0.203409],
#      'coefficients': [[0.021071, 0.990591]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.070564],
#      'coefficients': [[1.0]]}]},
#   '51': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [13289.383, 2010.5218, 441.69815],
#      'coefficients': [[0.060984, 0.366849, 0.69105]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [598.889, 130.0385, 42.13286],
#      'coefficients': [[-0.11272, 0.082644, 0.970258]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [51.51333, 24.43595, 7.420931],
#      'coefficients': [[-0.277043, 0.057503, 1.084703]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [7.314235, 2.844053, 1.105855],
#      'coefficients': [[-0.440381, 0.473734, 0.822135]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.278637, 0.241232],
#      'coefficients': [[-0.601695, 1.258692]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.08663],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [598.889, 130.0385, 42.13286],
#      'coefficients': [[0.153067, 0.613597, 0.391699]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [51.51333, 24.43595, 7.420931],
#      'coefficients': [[-0.13787, 0.536355, 0.650868]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [7.314235, 2.844053, 1.105855],
#      'coefficients': [[0.015305, 0.516083, 0.538757]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.278637, 0.241232],
#      'coefficients': [[0.022253, 0.989643]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.08663],
#      'coefficients': [[1.0]]}]},
#   '52': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [13796.56, 2088.8798, 459.39319],
#      'coefficients': [[0.061086, 0.366963, 0.690794]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [623.2631, 135.36, 44.00048],
#      'coefficients': [[-0.11282, 0.082252, 0.970601]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [54.19078, 25.82039, 7.809583],
#      'coefficients': [[-0.274412, 0.05183, 1.087622]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [7.764217, 3.043932, 1.199253],
#      'coefficients': [[-0.446731, 0.46947, 0.829811]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.340364, 0.278088],
#      'coefficients': [[-0.59047, 1.281968]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.096726],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [623.2631, 135.36, 44.00048],
#      'coefficients': [[0.153419, 0.6149, 0.389516]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [54.19078, 25.82039, 7.809583],
#      'coefficients': [[-0.143331, 0.539188, 0.652285]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [7.764217, 3.043932, 1.199253],
#      'coefficients': [[0.012746, 0.522123, 0.532661]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.340364, 0.278088],
#      'coefficients': [[0.025588, 0.987102]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.096726],
#      'coefficients': [[1.0]]}]},
#   '53': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [14351.186, 2173.0741, 477.87205],
#      'coefficients': [[0.061003, 0.36664, 0.691131]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [648.1887, 140.3064, 45.6988],
#      'coefficients': [[-0.112851, 0.083228, 0.969752]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [56.69469, 27.48875, 8.209096],
#      'coefficients': [[-0.273697, 0.0465, 1.091576]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [8.191679, 3.244596, 1.300489],
#      'coefficients': [[-0.450828, 0.463209, 0.838636]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.45138, 0.328103],
#      'coefficients': [[-0.665852, 1.328584]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.115076],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [648.1887, 140.3064, 45.6988],
#      'coefficients': [[0.154114, 0.619462, 0.383758]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [56.69469, 27.48875, 8.209096],
#      'coefficients': [[-0.152322, 0.543769, 0.656168]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [8.191679, 3.244596, 1.300489],
#      'coefficients': [[0.01187, 0.526525, 0.526608]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.45138, 0.328103],
#      'coefficients': [[0.027541, 0.985137]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.115076],
#      'coefficients': [[1.0]]}]},
#   '54': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [14902.236, 2256.5383, 496.37317],
#      'coefficients': [[0.060997, 0.366629, 0.691115]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [673.6611, 145.8491, 47.57708],
#      'coefficients': [[-0.112913, 0.082905, 0.970029]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [59.16752, 28.61159, 8.596596],
#      'coefficients': [[-0.273977, 0.04553, 1.092528]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [8.638676, 3.462818, 1.40104],
#      'coefficients': [[-0.455841, 0.461736, 0.844288]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.578474, 0.375081],
#      'coefficients': [[-0.727772, 1.362797]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.133179],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [673.6611, 145.8491, 47.57708],
#      'coefficients': [[0.154427, 0.620617, 0.382004]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [59.16752, 28.61159, 8.596596],
#      'coefficients': [[-0.151857, 0.547151, 0.651954]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [8.638676, 3.462818, 1.40104],
#      'coefficients': [[0.009585, 0.529819, 0.523598]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1.578474, 0.375081],
#      'coefficients': [[0.028072, 0.984264]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.133179],
#      'coefficients': [[1.0]]}]},
#   '55': {'electron_shells': [{'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [15525.866, 2349.0055, 516.23555],
#      'coefficients': [[0.060724, 0.365842, 0.692047]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [687.50505, 67.191157, 27.992003],
#      'coefficients': [[-0.110213, 0.727203, 0.340143]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [60.168188, 10.868694, 4.740705],
#      'coefficients': [[-0.275315, 0.890128, 0.264863]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [9.887163, 2.369343, 1.141676],
#      'coefficients': [[-0.368827, 0.832582, 0.388789]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [1.769078, 0.38362, 0.171306],
#      'coefficients': [[-0.340942, 0.700097, 0.493452]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.211849, 0.040324],
#      'coefficients': [[-0.275022, 0.193604]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [0],
#      'exponents': [0.017058],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [1024.2833, 239.64889, 71.255548],
#      'coefficients': [[0.079185, 0.419933, 0.643251]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [139.45864, 25.81081, 10.139452],
#      'coefficients': [[-0.033123, 0.389108, 0.679033]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [4.324244, 1.936415, 0.814505],
#      'coefficients': [[0.381669, 0.576976, 0.115405]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.594584],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.274992],
#      'coefficients': [[1.0]]},
#     {'function_type': 'gto',
#      'region': 'valence',
#      'angular_momentum': [1],
#      'exponents': [0.111553],
#      'coefficients': [[1.0]]}]}}}

# %%
with open("3-21g.json", "w") as f:
    json.dump(bc.as_dict(), f, indent=4)
